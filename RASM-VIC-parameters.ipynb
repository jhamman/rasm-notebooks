# %%
from netCDF4 import Dataset,num2date, date2num,date2index
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.basemap import Basemap, cm

# %%
f = Dataset('/usr1/jhamman/RASM/VIC/soil_param/params.nc','r')
AreaFract = f.variables['AreaFract'][:]
Cv = f.variables['Cv'][:]
lats = f.variables['yc'][:]
lons = f.variables['xc'][:]
f.close()

# %%
total = AreaFract.sum(axis=0)
fig = plt.figure(figsize=(6,6))
latmin=35
m = Basemap(projection='npstere', lon_0=-114, lat_ts=80.5, resolution='c',boundinglat=latmin)
xi, yi = m(lons, lats)
m.pcolor(xi,yi,total)
m.drawparallels(np.arange(-80.,81.,20.))
m.drawmeridians(np.arange(-180.,181.,20.))
m.drawcoastlines(color='k');
m.colorbar(location='bottom')

fig2=plt.figure(figsize=(6,6))
m.pcolor(xi,yi,Cv.sum(axis=0))
m.drawparallels(np.arange(-80.,81.,20.))
m.drawmeridians(np.arange(-180.,181.,20.))
m.drawcoastlines(color='k');
m.colorbar(location='bottom')
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x14843950>
